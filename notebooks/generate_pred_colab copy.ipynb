# %%
# !ssh-keygen -t ed25519 -C "th.barand@gmail.com" -f /root/.ssh/id_ed25519 -N ""
# Out:
# Generating public/private ed25519 key pair.
# Created directory '/root/.ssh'.
# Your identification has been saved in /root/.ssh/id_ed25519
# Your public key has been saved in /root/.ssh/id_ed25519.pub
# The key fingerprint is:
# SHA256:4Fo3ZYSV6XkAiGxmgJSXYltkjJ/K+KsR9KYS/LBiNeU th.barand@gmail.com
# The key's randomart image is:
# +--[ED25519 256]--+
# |.o*=.. ..+oo     |
# |.=.=* . ..+      |
# |..*+...  .oo     |
# |o..oo. . oo .    |
# |=o.= Eo S  .     |
# |.=B .o . .       |
# |+= ..            |
# |+..              |
# |....             |
# +----[SHA256]-----+

# %%
# !cat /root/.ssh/id_ed25519.pub
# Out:
# ssh-ed25519 AAAAC3NzaC1lZDI1NTE5AAAAIL6oeyeUh8hvn9rtqKeo/gV2co0njYgMLsETqR0vrmM8 th.barand@gmail.com

# %%
# !mkdir -p /root/.ssh
# !chmod 700 /root/.ssh
# !chmod 600 /root/.ssh/id_ed25519
# !echo -e "Host github.com\n\tStrictHostKeyChecking no\n\tIdentityFile /root/.ssh/id_ed25519" > /root/.ssh/config

# 4. Test SSH connection (optional but recommended)
# !ssh -T git@github.com
# Out:
# ...
# Hi thomas0barand! You've successfully authenticated, but GitHub does not provide shell access.

# %%
# 5. Clone using SSH URL
# !git clone git@github.com:thomas0barand/data-science-browser.git

# 6. Checkout the branch
# %cd data-science-browser
# !git checkout thomas
# Out:
# Cloning into 'data-science-browser'...
# remote: Enumerating objects: 159, done.
# remote: Counting objects: 100% (159/159), done.
# remote: Compressing objects: 100% (112/112), done.
# remote: Total 159 (delta 68), reused 134 (delta 43), pack-reused 0 (from 0)
# Receiving objects: 100% (159/159), 5.48 MiB | 12.18 MiB/s, done.
# Resolving deltas: 100% (68/68), done.
# /content/data-science-browser
# Branch 'thomas' set up to track remote branch 'thomas' from 'origin'.
# Switched to a new branch 'thomas'

# %%
# Out:
# data  import.log  outputs	  README.md	     RESULTS_SUMMARY.md  src
# docs  notebooks   pyproject.toml  README_scripts.md  scripts

# %%
# !python scripts/generate_predictions.py --method bigram
# Out:
# Generating predictions using Bigram TF-IDF
# Loading embeddings...
# ✓ 26657 docs, 5000 terms
# Pre-computing norms...
# Identifying queries and corpus...
# ✓ 1000 queries, 25657 corpus
# ✓ Starting: 1000 queries
# Processing 1000 queries...
# Queries:   2% 21/1000 [01:45<1:20:52,  4.96s/it]Exception ignored in: <generator object tqdm.__iter__ at 0x787efb1003a0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/std.py", line 1196, in __iter__
#     self.close()
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/std.py", line 1275, in close
#     self._decr_instances(self)
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/std.py", line 707, in _decr_instances
#     instances = list(filter(
#                      ^^^^^^^
# KeyboardInterrupt:
# Traceback (most recent call last):
#   File "/content/data-science-browser/scripts/generate_predictions.py", line 321, in <module>
#     main()
# ...
